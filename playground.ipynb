# %% [markdown]
# # Analysing Homegate data
#
# A plaground to transform and analyise scraped Homegate data.

# %% [markdown]
# ## 1. Load data

# %%
from frictionless import Resource
res = Resource("data/homegate.resource.yaml")
res.to_petl().display(limit=8)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>id</th>
# <th>object_ref</th>
# <th>category</th>
# <th>date</th>
# <th>type</th>
# <th>floor</th>
# <th>rent</th>
# <th>rent_add</th>
# <th>rent_net</th>
# <th>rooms</th>
# <th>area</th>
# <th>year_built</th>
# <th>street_number</th>
# <th>city</th>
# <th>zip</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>3001314971</td>
# <td>ig6dw.46r3z</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.316264</td>
# <td></td>
# <td>4</td>
# <td>520</td>
# <td></td>
# <td></td>
# <td></td>
# <td>19</td>
# <td></td>
# <td>Blumenbergplatz 5</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3001087436</td>
# <td>146.1.10.800384.d8ee1213-8011-11eb-8e73-005056bdbc06</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.376172</td>
# <td></td>
# <td>3</td>
# <td>550</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td>Linsebühlstrasse 18</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3001237053</td>
# <td>152801.01.00402</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.396096</td>
# <td></td>
# <td>4</td>
# <td>530</td>
# <td></td>
# <td></td>
# <td></td>
# <td>28</td>
# <td>1962</td>
# <td>Vonwilstr. 15</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3001051234</td>
# <td>10738.10738.1012</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.452852</td>
# <td></td>
# <td>1</td>
# <td>600</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td>Brauerstrasse 3</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3000763958</td>
# <td>StGallen</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.540689</td>
# <td></td>
# <td></td>
# <td>550</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td>Schützengasse</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3001381704</td>
# <td>51219.01.6001</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.595315</td>
# <td></td>
# <td>5</td>
# <td>100</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td>1905</td>
# <td>Burggraben 26</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3001292565</td>
# <td>Linsen68.16841</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.617437</td>
# <td></td>
# <td>1</td>
# <td>475</td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td></td>
# <td>Linsenbühlstrasse 68</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# <tr>
# <td>3001209766</td>
# <td>050-07.07.830758.b9c75053-b227-11eb-820b-005056bdbc06</td>
# <td>rent</td>
# <td>2021-09-30T14:31:08.636397</td>
# <td></td>
# <td>4</td>
# <td>1850</td>
# <td></td>
# <td></td>
# <td></td>
# <td>101</td>
# <td>2000</td>
# <td>Oberer Graben 37</td>
# <td>St. Gallen</td>
# <td>9000</td>
# </tr>
# </tbody>
# </table>
# <p><strong>...</strong></p>

# %% [markdown]
# ## 2. Geocode addresses
#
# Using Swisstopos Geocoder translate address strings like `Fähnernstrasse 3 9000 St. Gallen` into a `WKT Point` and `EGID`.

# %%
from urllib import parse
import requests
from frictionless.plugins.json import JsonDialect
from frictionless import Resource

def geo_code_swisstopo(addressString=None, attribute="geom"):
    params = parse.urlencode(dict(
        type="locations",
        searchText=addressString,  # "Fähnernstrasse 3 9000 St. Gallen"
    ))

    url = f"https://api3.geo.admin.ch/rest/services/ech/SearchServer?{params}"

    res = requests.get(url)
    if res.status_code == 200:
        result = res.json()
        if "results" in result.keys() and len(result["results"]) > 0:
            likely_match = result["results"][0]["attrs"]
            if attribute == "geom":
                return f"POINT ({likely_match['lon']} {likely_match['lat']})"
            elif attribute == "egid":
                return likely_match["featureId"]
            else:
                return None

print(f'GEOM: {geo_code_swisstopo("Fähnernstrasse 3 9000 St. Gallen", "geom")}, EGID: {geo_code_swisstopo("Fähnernstrasse 3 9000 St. Gallen", "egid")}')
# Out:
# GEOM: POINT (9.362982749938965 47.41105270385742), EGID: 1071458_0

# %%
from frictionless import transform, steps, Resource

out = transform(
    "data/homegate.resource.yaml",
    steps=[
        steps.table_normalize(),
        steps.field_add(name="address", function=lambda row: f"{row['street_number']}, {row['zip']} {row['city']}"),
        steps.table_normalize(),
        steps.field_add(name="_geom", function=lambda row: geo_code_swisstopo(row["address"], "geom")),
        steps.field_add(name="EGID", function=lambda row: geo_code_swisstopo(row["address"], "egid")),
        steps.table_normalize(),
        steps.table_write(path="data/homegate-geocoded.csv"),
        steps.row_filter(formula="_geom is not None"),
        steps.table_write(path="data/homegate-geocoded.geojson"),
    ]
)

out.to_petl()
# Out:
# +------------+--------------------------------------------------------+----------+---------------------------------------------------+------+-------+------+----------+----------+-------+------+------------+-----------------------+--------------+------+----------------------------------------+-----------------------------------------------+-------------+
# | id         | object_ref                                             | category | date                                              | type | floor | rent | rent_add | rent_net | rooms | area | year_built | street_number         | city         | zip  | address                                | _geom                                         | EGID        |
# +============+========================================================+==========+===================================================+======+=======+======+==========+==========+=======+======+============+=======================+==============+======+========================================+===============================================+=============+
# | 3001314971 | 'ig6dw.46r3z'                                          | 'rent'   | datetime.datetime(2021, 9, 30, 14, 31, 8, 316264) | None | '4'   |  520 | None     | None     | None  |   19 | None       | 'Blumenbergplatz 5'   | 'St. Gallen' | 9000 | 'Blumenbergplatz 5, 9000 St. Gallen'   | 'POINT (9.373247146606445 47.42692947387695)' | '1073079_0' |
# +------------+--------------------------------------------------------+----------+---------------------------------------------------+------+-------+------+----------+----------+-------+------+------------+-----------------------+--------------+------+----------------------------------------+-----------------------------------------------+-------------+
# | 3001087436 | '146.1.10.800384.d8ee1213-8011-11eb-8e73-005056bdbc06' | 'rent'   | datetime.datetime(2021, 9, 30, 14, 31, 8, 376172) | None | '3'   |  550 | None     | None     | None  | None | None       | 'Linsebühlstrasse 18' | 'St. Gallen' | 9000 | 'Linsebühlstrasse 18, 9000 St. Gallen' | 'POINT (9.381048202514648 47.42434310913086)' | '1073523_0' |
# +------------+--------------------------------------------------------+----------+---------------------------------------------------+------+-------+------+----------+----------+-------+------+------------+-----------------------+--------------+------+----------------------------------------+-----------------------------------------------+-------------+
# | 3001237053 | '152801.01.00402'                                      | 'rent'   | datetime.datetime(2021, 9, 30, 14, 31, 8, 396096) | None | '4'   |  530 | None     | None     | None  |   28 | '1962'     | 'Vonwilstr. 15'       | 'St. Gallen' | 9000 | 'Vonwilstr. 15, 9000 St. Gallen'       | 'POINT (9.35889720916748 47.417083740234375)' | '1070167_0' |
# +------------+--------------------------------------------------------+----------+---------------------------------------------------+------+-------+------+----------+----------+-------+------+------------+-----------------------+--------------+------+----------------------------------------+-----------------------------------------------+-------------+
# | 3001051234 | '10738.10738.1012'                                     | 'rent'   | datetime.datetime(2021, 9, 30, 14, 31, 8, 452852) | None | '1'   |  600 | None     | None     | None  | None | None       | 'Brauerstrasse 3'     | 'St. Gallen' | 9000 | 'Brauerstrasse 3, 9000 St. Gallen'     | 'POINT (9.399625778198242 47.43373107910156)' | '1076226_0' |
# +------------+--------------------------------------------------------+----------+---------------------------------------------------+------+-------+------+----------+----------+-------+------+------------+-----------------------+--------------+------+----------------------------------------+-----------------------------------------------+-------------+
# | 3000763958 | 'StGallen'                                             | 'rent'   | datetime.datetime(2021, 9, 30, 14, 31, 8, 540689) | None | None  |  550 | None     | None     | None  | None | None       | 'Schützengasse'       | 'St. Gallen' | 9000 | 'Schützengasse, 9000 St. Gallen'       | 'POINT (9.372462272644043 47.42345428466797)' | '1072433_0' |
# +------------+--------------------------------------------------------+----------+---------------------------------------------------+------+-------+------+----------+----------+-------+------+------------+-----------------------+--------------+------+----------------------------------------+-----------------------------------------------+-------------+
# ...

# %% [markdown]
# ## 3. Basic statistics

# %%
from frictionless import transform, steps, Resource
from statistics import mean, median

avg = transform(
    "data/homegate-geocoded.csv",
    steps=[
        steps.row_filter(formula="area is not ''"),
        steps.row_filter(formula="int(area) > 20"),
        steps.table_normalize(),
        steps.field_add(name="price_per_sqm", type="number", formula="int(rent) / int(area)"),
        steps.table_aggregate(group_name="zip", aggregation={"mean": ("price_per_sqm", mean)}),
        steps.table_normalize(),
        steps.row_sort(field_names=["mean"], reverse=True),
    ]
)

avg.to_petl().display(limit=20)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>zip</th>
# <th>mean</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='text-align: right'>9011</td>
# <td style='text-align: right'>19.912557860030965</td>
# </tr>
# <tr>
# <td style='text-align: right'>9014</td>
# <td style='text-align: right'>18.648775906376258</td>
# </tr>
# <tr>
# <td style='text-align: right'>9015</td>
# <td style='text-align: right'>18.55923119775</td>
# </tr>
# <tr>
# <td style='text-align: right'>9000</td>
# <td style='text-align: right'>18.558260824277088</td>
# </tr>
# <tr>
# <td style='text-align: right'>9012</td>
# <td style='text-align: right'>17.463714734368953</td>
# </tr>
# <tr>
# <td style='text-align: right'>9016</td>
# <td style='text-align: right'>17.11492787250551</td>
# </tr>
# <tr>
# <td style='text-align: right'>9008</td>
# <td style='text-align: right'>17.03641524671511</td>
# </tr>
# <tr>
# <td style='text-align: right'>9010</td>
# <td style='text-align: right'>16.949081180170214</td>
# </tr>
# </tbody>
# </table>

# %%
avg = transform(
    "data/homegate-geocoded.csv",
    steps=[
        steps.row_filter(formula="area is not ''"),
        steps.row_filter(formula="int(area) > 20"),
        steps.table_normalize(),
        steps.field_add(name="price_per_sqm", type="number", formula="int(rent) / int(area)"),
        steps.table_aggregate(group_name="zip", aggregation={"median": ("price_per_sqm", median)}),
        steps.table_normalize(),
        steps.row_sort(field_names=["median"], reverse=True),
    ]
)

avg.to_petl().display(limit=20)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>zip</th>
# <th>median</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style='text-align: right'>9011</td>
# <td style='text-align: right'>19.885714285714286</td>
# </tr>
# <tr>
# <td style='text-align: right'>9000</td>
# <td style='text-align: right'>17.72222222222222</td>
# </tr>
# <tr>
# <td style='text-align: right'>9012</td>
# <td style='text-align: right'>17.636363636363637</td>
# </tr>
# <tr>
# <td style='text-align: right'>9014</td>
# <td style='text-align: right'>17.51185322613894</td>
# </tr>
# <tr>
# <td style='text-align: right'>9016</td>
# <td style='text-align: right'>17.4025974025974</td>
# </tr>
# <tr>
# <td style='text-align: right'>9015</td>
# <td style='text-align: right'>17.25</td>
# </tr>
# <tr>
# <td style='text-align: right'>9010</td>
# <td style='text-align: right'>16.8577648766328</td>
# </tr>
# <tr>
# <td style='text-align: right'>9008</td>
# <td style='text-align: right'>16.53488372093023</td>
# </tr>
# </tbody>
# </table>
